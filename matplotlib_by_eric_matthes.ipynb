# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Plots from krish naik tutorial
a = np.arange(0,10)
b = np.arange(10,20)
x = np.arange(40,50)
y = np.arange(50,60)

# Creating multiple plots or subplots in one diagram.
plt.subplot(2,2,1) # plt.subplot(raw, column, index)
plt.plot(x,y,c='g')
plt.subplot(2,2,2) # 2 raws 2 columns and 2nd position.and
plt.plot(y,y**y,c='m')
plt.subplot(2,2,4) # this plot will go to 4th position
plt.plot(y*(-a),x,c='b')

# %%
squares = [x**2 for x in range(1,6)]
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
plt.plot(squares)

# %%
fig, ax = plt.subplots()
ax.plot(squares)

# %%
# The function plt.subplots() can generate one or more plots in the same fig­ure. The variable fig represents the entire figure or collection of plots thatare generated. The variable ax represents a single plot in the figure and is the variable we’ll use most of the time.
 
fig, ax = plt.subplots()
ax.plot(squares,'g-o', line)

# %%
plt.subplots()
plt.plot(squares)
