# %% [markdown]
# ### Topics Covered
# 1. Import pandas
# 2. Rading CSV with read_csv, ease of using pandas read_csv vs native python's csv module.
# 3. DataFrames the backbone of pandas.
# 4. df.shape for checking raws and columns.
# 5. df.info() for understanding more about data.
# 6. Pandas setting to read coustumized number of raws and columns in a DataFrame.
#     - pd.set_option('display.max_columns', number of columns you want to see)
#     - pd.set_option('display.max_raws', number of raws you want to see)
# 7. df.haed()
# 8. Isponce video add

# %%
import pandas as pd

# %%
path = r"E:\Project\Anaconda\csv\stackoverflow\survey_results_public.csv"
job_candidates = r"E:\Project\Anaconda\csv\csv\job_candidates"
df = pd.read_csv(path)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.head(50)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1                     I am a developer by profession      Yes
# 1            2                     I am a developer by profession       No
# 2            3                        I code primarily as a hobby      Yes
# 3            4                     I am a developer by profession      Yes
# 4            5  I used to be a developer by profession, but no...      Yes
# 5            6                     I am a developer by profession       No
# 6            7                     I am a developer by profession      Yes
# 7            8                     I am a developer by profession      Yes
# 8            9                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# ...

# %%
df.size
# Out:
# 3932121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df_1 = pd.read_csv(path, usecols=['MainBranch','Age','Gender','Country','DatabaseDesireNextYear','DatabaseWorkedWith',
                                 'LanguageDesireNextYear','LanguageWorkedWith','WebframeDesireNextYear'],)

# %%
df_1.head(100)
# Out:
#                                            MainBranch   Age  \
# 0                      I am a developer by profession   NaN
# 1                      I am a developer by profession   NaN
# 2                         I code primarily as a hobby   NaN
# 3                      I am a developer by profession  25.0
# 4   I used to be a developer by profession, but no...  31.0
# ..                                                ...   ...
# 95                     I am a developer by profession  30.0
# 96                     I am a developer by profession  29.0
# 97                     I am a developer by profession  30.0
# 98                     I am a developer by profession  42.0
# 99                     I am a developer by profession  55.0
#
#                Country DatabaseDesireNextYear  \
# 0              Germany   Microsoft SQL Server
# 1       United Kingdom                    NaN
# 2   Russian Federation                    NaN
# 3              Albania                    NaN
# ...

# %%
df_1 = pd.read_csv(path, header=None, seq
                   usecols=['MainBranch','Age','Gender','Country','DatabaseDesireNextYear','DatabaseWorkedWith',
                            'LanguageDesireNextYear','LanguageWorkedWith','WebframeDesireNextYear'])
# Out:
#   File "<ipython-input-9-520f5a60a818>", line 2
#     usecols=['MainBranch','Age','Gender','Country','DatabaseDesireNextYear','DatabaseWorkedWith',
#           ^
# SyntaxError: invalid syntax

# %%
len(['MainBranch','Age','Gender','Country','DatabaseDesireNextYear','DatabaseWorkedWith',
                            'LanguageDesireNextYear','LanguageWorkedWith','WebframeDesireNextYear'])

# %%
pd.set_option('display.max_columns',85) # This line will tell pandas to view every time 85 columns insted of showing
                                        # starting and ending 4 columns
pd.set_option('display.max_raws',85)    # This line is for showing 85 raws

# %%
s = 'DatabaseDesireNextYear' 
d = 'DatabaseWorkedWith'
df.loc[:,d]
